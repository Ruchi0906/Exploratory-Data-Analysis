# %%
import pandas as pd
from warnings import filterwarnings
filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Read Data

# %%
A = pd.read_csv("C:/Users/Ruchita/Desktop/Data Science/Datasets/Cars93.csv")

# %%
A.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %% [markdown]
# # Profile

# %%
A.shape
# Out:
# (93, 28)

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             89 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
A.describe()
# Out:
#               id  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count  93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean   47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std    26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min     1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%    24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%    47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%    70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max    93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %% [markdown]
# # Drop Unncessary Columns

# %%
A.nunique()
# Out:
# id                    93
# Manufacturer          32
# Model                 93
# Type                   6
# Min.Price             79
# Price                 81
# Max.Price             79
# MPG.city              21
# MPG.highway           22
# AirBags                3
# DriveTrain             3
# Cylinders              6
# EngineSize            26
# Horsepower            57
# RPM                   24
# Rev.per.mile          78
# Man.trans.avail        2
# Fuel.tank.capacity    38
# Passengers             6
# Length                51
# Wheelbase             27
# Width                 16
# Turn.circle           14
# Rear.seat.room        24
# Luggage.room          16
# Weight                81
# Origin                 2
# Make                  93
# dtype: int64

# %%
A = A.drop(labels=["id","Make","Model"],axis=1)

# %% [markdown]
# # Replace Null Values

# %%
A.isna().sum()
# Out:
# Manufacturer           0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                4
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# dtype: int64

# %%
def Replace_nan(df):
    q=pd.DataFrame(df.isna().sum(),columns=["Count_nan"])
    for i in q[q.Count_nan>0].index:
        if(df[i].dtypes=='object'):
            x=df[i].mode()[0]
            df[i]=df[i].fillna(x)
        else:
            y=round(df[i].mean(),2)
            df[i]=df[i].fillna(y)

# %%
Replace_nan(A)

# %% [markdown]
# # EDA

# %% [markdown]
# # Univarate Analysis

# %%
for i in A.columns:
    if(A[i].dtypes=='object'):
        print(i)
# Out:
# Manufacturer
# Type
# AirBags
# DriveTrain
# Cylinders
# Man.trans.avail
# Origin

# %%
A['Manufacturer'].value_counts().nlargest(20).plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))

A["AirBags"].value_counts().plot(kind="pie")
plt.title("PieChart of Airbags Columns")
# Out:
# Text(0.5, 1.0, 'PieChart of Airbags Columns')

# %%
plt.figure(figsize=(5,5))
sb.countplot(x="Origin",data=A)
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='count'>

# %%
A["Type"].value_counts().plot(kind='barh')
plt.xlabel("Types of Car")
plt.ylabel("No. of Cars")
# Out:
# Text(0, 0.5, 'No. of Cars')

# %%
A["Cylinders"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Cylinders'>

# %%
A["DriveTrain"].value_counts().plot(kind='bar')
plt.ylabel("No. of Cars")
# Out:
# Text(0, 0.5, 'No. of Cars')

# %%
sb.distplot(A["Price"])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sb.histplot(A["MPG.city"])
plt.ylabel("No. of Cars")
# Out:
# Text(0, 0.5, 'No. of Cars')

# %%
A["Length"].plot(kind="hist")
plt.xlabel("Length")
plt.ylabel("No. of Cars")
# Out:
# Text(0, 0.5, 'No. of Cars')

# %%
sb.distplot(A["Horsepower"])
# Out:
# <AxesSubplot:xlabel='Horsepower', ylabel='Density'>

# %%
plt.hist(A["RPM"])
plt.xlabel("RPM")
plt.ylabel("No. Of Cars")
# Out:
# Text(0, 0.5, 'No. Of Cars')

# %%
sb.histplot(A["Weight"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Count'>

# %% [markdown]
# # Bivarate Analysis

# %%
plt.figure(figsize=(20,50))
q=1
for i in A.columns:
    if(A[i].dtypes=='object'):
        
        if((len(A[i].unique()))>10):
            plt.subplot(8,1,q)
            g = sb.boxplot(x=i,y="Price",data = A)
            plt.xticks(rotation=35)
        sb.boxplot(x=i,y="Price",data = A)
        plt.show()
        q = q+1

# %%
plt.figure(figsize=(20,60))
q=1
for i in A.columns:
    if(A[i].dtypes!='object'):
        plt.subplot(14,2,q)
        sb.scatterplot(x=i,y="Price",data = A)
        q = q+1
